# %% [markdown]
# # **Workflow Setup Notebook**
# ### Synching the Github repository and Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/i2dl
# !git pull
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/i2dl
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 1), reused 3 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 606 bytes | 8.00 KiB/s, done.
# From https://github.com/Louis-codes/TUM_deep_learning
#    3829298..869cb6f  main       -> origin/main
# Updating 3829298..869cb6f
# Fast-forward
#  00-i2dl-workflow-setup.ipynb | 33 +++++++++++++++++++++++++++++++++
#  1 file changed, 33 insertions(+)
#  create mode 100644 00-i2dl-workflow-setup.ipynb
