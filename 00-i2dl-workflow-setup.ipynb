# %% [markdown]
# # **Workflow Setup Notebook**
# ### Synching the Github repository and Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/i2dl
# !git pull
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/i2dl
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 44 (delta 31), reused 15 (delta 11), pack-reused 0 (from 0)
# Unpacking objects: 100% (44/44), 24.75 KiB | 6.00 KiB/s, done.
# From https://github.com/Louis-codes/TUM_deep_learning
#    ae023ec..6f7c1b3  main       -> origin/main
# Updating ae023ec..6f7c1b3
# Fast-forward
#  00-i2dl-workflow-setup.ipynb                       |   64 +-
#  01_PyTorch_test.ipynb                              |   79 +-
#  exercise_11/1_tokenizer.ipynb                      | 2368 ++++++++++++--------
#  exercise_11/2_embedding.ipynb                      |  527 +++--
#  exercise_11/3_attention.ipynb                      | 1853 +++++++--------
#  exercise_11/4_positional_encoding.ipynb            | 1142 +++++-----
#  exercise_11/exercise_code/network/attention.py     |   10 +-
#  exercise_11/exercise_code/network/embedding.py     |   15 +-
#  .../exercise_code/network/multi_head_attention.py  |   25 +-
#  9 files changed, 3402 insertions(+), 2681 deletions(-)
