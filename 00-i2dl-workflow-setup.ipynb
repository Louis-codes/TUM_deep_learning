# %% [markdown]
# # **Workflow Setup Notebook**
# ### Synching the Github repository and Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/i2dl
# !git pull
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/i2dl
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 33 (delta 6), reused 30 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (33/33), 810.84 KiB | 354.00 KiB/s, done.
# From https://github.com/Louis-codes/TUM_deep_learning
#    4bfe48c..ae023ec  main       -> origin/main
# Updating 4bfe48c..ae023ec
# Fast-forward
#  00-i2dl-workflow-setup.ipynb                       |  69 +-
#  exercise_11/1_tokenizer.ipynb                      | 988 +++++++++++++++++++++
#  exercise_11/2_embedding.ipynb                      | 242 +++++
#  exercise_11/3_attention.ipynb                      | 877 ++++++++++++++++++
#  exercise_11/4_positional_encoding.ipynb            | 552 ++++++++++++
#  exercise_11/exercise_code/data/__init__.py         |   0
#  exercise_11/exercise_code/data/tokenizer.py        | 193 ++++
#  exercise_11/exercise_code/network/__init__.py      |  34 +
#  exercise_11/exercise_code/network/attention.py     |  79 ++
#  exercise_11/exercise_code/network/embedding.py     | 118 +++
#  .../exercise_code/network/multi_head_attention.py  | 109 +++
#  exercise_11/exercise_code/tests/__init__.py        |   8 +
#  exercise_11/exercise_code/tests/attention_test.py  | 295 ++++++
#  exercise_11/exercise_code/tests/base_tests.py      | 261 ++++++
#  exercise_11/exercise_code/tests/embedding_test.py  | 128 +++
#  exercise_11/exercise_code/util/download_util.py    | 155 ++++
#  exercise_11/exercise_code/util/notebook_util.py    | 284 ++++++
#  exercise_11/exercise_code/util/submit.py           |  72 ++
#  exercise_11/exercise_code/util/transformer_util.py |  16 +
#  .../images/Transformer-Attention Head.drawio.png   | Bin 0 -> 455898 bytes
#  .../Transformer-AttentionMechanism.drawio.png      | Bin 0 -> 753558 bytes
#  .../Transformer-Multi Head Attention.drawio.png    | Bin 0 -> 484390 bytes
#  22 files changed, 4424 insertions(+), 56 deletions(-)
#  create mode 100644 exercise_11/1_tokenizer.ipynb
#  create mode 100644 exercise_11/2_embedding.ipynb
#  create mode 100644 exercise_11/3_attention.ipynb
#  create mode 100644 exercise_11/4_positional_encoding.ipynb
#  create mode 100644 exercise_11/exercise_code/data/__init__.py
#  create mode 100644 exercise_11/exercise_code/data/tokenizer.py
#  create mode 100644 exercise_11/exercise_code/network/__init__.py
#  create mode 100644 exercise_11/exercise_code/network/attention.py
#  create mode 100644 exercise_11/exercise_code/network/embedding.py
#  create mode 100644 exercise_11/exercise_code/network/multi_head_attention.py
#  create mode 100644 exercise_11/exercise_code/tests/__init__.py
#  create mode 100644 exercise_11/exercise_code/tests/attention_test.py
#  create mode 100644 exercise_11/exercise_code/tests/base_tests.py
#  create mode 100644 exercise_11/exercise_code/tests/embedding_test.py
#  create mode 100644 exercise_11/exercise_code/util/download_util.py
#  create mode 100644 exercise_11/exercise_code/util/notebook_util.py
#  create mode 100644 exercise_11/exercise_code/util/submit.py
#  create mode 100644 exercise_11/exercise_code/util/transformer_util.py
#  create mode 100644 exercise_11/images/Transformer-Attention Head.drawio.png
#  create mode 100644 exercise_11/images/Transformer-AttentionMechanism.drawio.png
#  create mode 100644 exercise_11/images/Transformer-Multi Head Attention.drawio.png
