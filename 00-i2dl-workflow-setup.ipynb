# %% [markdown]
# # **Workflow Setup Notebook**
# ### Synching the Github repository and Google Drive

# %%
from google.colab import drive    # Python
drive.mount('/content/drive')      # Python
# %cd /content/drive/MyDrive/i2dl    # magic
# !git pull                          # shell
