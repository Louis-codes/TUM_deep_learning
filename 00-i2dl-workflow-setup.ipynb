# %% [markdown]
# # **Workflow Setup Notebook**
# ### Synching the Github repository and Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/i2dl
# !git pull
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/i2dl
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 36 (delta 4), reused 35 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (36/36), 532.29 KiB | 219.00 KiB/s, done.
# From https://github.com/Louis-codes/TUM_deep_learning
#    8bd6813..883a8cd  main       -> origin/main
# Updating 8bd6813..883a8cd
# Fast-forward
#  exercise_08/1_Autoencoder.ipynb                    |  99 ++--------
#  exercise_09/1_facial_keypoints.ipynb               |   1 +
#  exercise_09/Optional-spatial_batchnorm.ipynb       |   1 +
#  exercise_09/exercise_code/__init__.py              |   0
#  exercise_09/exercise_code/data/__init__.py         |   0
#  exercise_09/exercise_code/data/base_dataset.py     |  25 +++
#  exercise_09/exercise_code/data/download_utils.py   | 124 ++++++++++++
#  .../exercise_code/data/facial_keypoints_dataset.py |  46 +++++
#  exercise_09/exercise_code/layers.py                | 218 +++++++++++++++++++++
#  .../networks/SpatialBatchNormModel.py              | 166 ++++++++++++++++
#  exercise_09/exercise_code/networks/__init__.py     |   6 +
#  exercise_09/exercise_code/networks/keypoint_nn.py  |  87 ++++++++
#  exercise_09/exercise_code/tests/__init__.py        |   3 +
#  exercise_09/exercise_code/tests/base_tests.py      | 148 ++++++++++++++
#  exercise_09/exercise_code/tests/eval_utils.py      |  10 +
#  exercise_09/exercise_code/tests/gradient_check.py  | 126 ++++++++++++
#  .../exercise_code/tests/keypoint_nn_tests.py       | 108 ++++++++++
#  .../exercise_code/tests/spatial_batchnorm_tests.py | 127 ++++++++++++
#  exercise_09/exercise_code/util/__init__.py         |   4 +
#  exercise_09/exercise_code/util/save_model.py       |  18 ++
#  exercise_09/exercise_code/util/submit.py           |  72 +++++++
#  exercise_09/exercise_code/util/vis_utils.py        |  19 ++
#  exercise_09/images/SpatialBatchNorm.JPG            | Bin 0 -> 99802 bytes
#  exercise_09/images/key_pts_example.png             | Bin 0 -> 346539 bytes
#  exercise_09/images/key_pts_expl.png                | Bin 0 -> 60815 bytes
#  25 files changed, 1322 insertions(+), 86 deletions(-)
#  create mode 100644 exercise_09/1_facial_keypoints.ipynb
#  create mode 100644 exercise_09/Optional-spatial_batchnorm.ipynb
#  create mode 100644 exercise_09/exercise_code/__init__.py
#  create mode 100644 exercise_09/exercise_code/data/__init__.py
#  create mode 100644 exercise_09/exercise_code/data/base_dataset.py
#  create mode 100644 exercise_09/exercise_code/data/download_utils.py
#  create mode 100644 exercise_09/exercise_code/data/facial_keypoints_dataset.py
#  create mode 100644 exercise_09/exercise_code/layers.py
#  create mode 100644 exercise_09/exercise_code/networks/SpatialBatchNormModel.py
#  create mode 100644 exercise_09/exercise_code/networks/__init__.py
#  create mode 100644 exercise_09/exercise_code/networks/keypoint_nn.py
#  create mode 100644 exercise_09/exercise_code/tests/__init__.py
#  create mode 100644 exercise_09/exercise_code/tests/base_tests.py
#  create mode 100644 exercise_09/exercise_code/tests/eval_utils.py
#  create mode 100644 exercise_09/exercise_code/tests/gradient_check.py
#  create mode 100644 exercise_09/exercise_code/tests/keypoint_nn_tests.py
#  create mode 100644 exercise_09/exercise_code/tests/spatial_batchnorm_tests.py
#  create mode 100644 exercise_09/exercise_code/util/__init__.py
#  create mode 100644 exercise_09/exercise_code/util/save_model.py
#  create mode 100644 exercise_09/exercise_code/util/submit.py
#  create mode 100644 exercise_09/exercise_code/util/vis_utils.py
#  create mode 100644 exercise_09/images/SpatialBatchNorm.JPG
#  create mode 100644 exercise_09/images/key_pts_example.png
#  create mode 100644 exercise_09/images/key_pts_expl.png

# %%
import os

# Change directory to the repository to ensure git commands run in the correct context
# %cd /content/drive/MyDrive/i2dl

# Discard local changes to the specific file
# !git checkout -- exercise_07/1_pytorch.ipynb
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_3246/1632203207.py", line 4, in <cell line: 0>
#     get_ipython().run_line_magic('cd', '/content/drive/MyDrive/i2dl')
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#                               ^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
#              ^^^^^^^^^^^
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 1769, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 1714, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 970, in getsourcefile
#     module = getmodule(object, filename)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 999, in getmodule
#     file = getabsfile(object, _filename)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 983, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen posixpath>", line 412, in abspath
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_3246/1632203207.py", line 4, in <cell line: 0>
#     get_ipython().run_line_magic('cd', '/content/drive/MyDrive/i2dl')
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#                               ^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
#              ^^^^^^^^^^^
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 1769, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 1714, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 970, in getsourcefile
#     module = getmodule(object, filename)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 999, in getmodule
#     file = getabsfile(object, _filename)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 983, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen posixpath>", line 412, in abspath
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_3246/1632203207.py", line 4, in <cell line: 0>
#     get_ipython().run_line_magic('cd', '/content/drive/MyDrive/i2dl')
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2418, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "<decorator-gen-85>", line 2, in cd
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#                               ^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/magics/osm.py", line 342, in cd
#     oldcwd = os.getcwd()
#              ^^^^^^^^^^^
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 1769, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 1714, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 970, in getsourcefile
#     module = getmodule(object, filename)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 999, in getmodule
#     file = getabsfile(object, _filename)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/inspect.py", line 983, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen posixpath>", line 412, in abspath
# OSError: [Errno 107] Transport endpoint is not connected

# %%
# Now that local changes are discarded, try pulling again
# !git pull
# Out:
# Updating 7e3f0a6..92cc327
# Updating files: 100% (31/31), done.
# Fast-forward
#  00-i2dl-workflow-setup.ipynb                       |   28 +-
#  01_math_recap.ipynb                                |  285 ++-
#  exercise_07/1_pytorch.ipynb                        | 1854 +++++++++++++++++++-
#  exercise_07/2_tensorboard.ipynb                    | 1601 ++++++++++++++++-
#  exercise_07/3_Cifar10_Pytorch.ipynb                |  762 +++++++-
#  exercise_08/1_Autoencoder.ipynb                    |  991 +++++++++++
#  .../Optional-BatchNormalization_Dropout.ipynb      |    1 +
#  exercise_08/exercise_code/.empty                   |    0
#  exercise_08/exercise_code/BatchNormModel.py        |  184 ++
#  exercise_08/exercise_code/Util.py                  |  108 ++
#  exercise_08/exercise_code/base_dataset.py          |   55 +
#  exercise_08/exercise_code/download_utils.py        |  136 ++
#  exercise_08/exercise_code/image_folder_dataset.py  |   46 +
#  exercise_08/exercise_code/layers.py                |  232 +++
#  exercise_08/exercise_code/models.py                |  253 +++
#  exercise_08/exercise_code/submit.py                |   72 +
#  exercise_08/exercise_code/tests/__init__.py        |    3 +
#  exercise_08/exercise_code/tests/base_tests.py      |  274 +++
#  exercise_08/exercise_code/tests/eval_utils.py      |   22 +
#  exercise_08/exercise_code/tests/grad_tests.py      |   48 +
#  .../exercise_code/tests/gradient_check_utils.py    |  124 ++
#  exercise_08/img/autoencoder.png                    |  Bin 0 -> 75687 bytes
#  exercise_08/img/batchnorm.jpg                      |  Bin 0 -> 67952 bytes
#  exercise_08/img/dropout.jpg                        |  Bin 0 -> 64193 bytes
#  exercise_08/img/network_split.png                  |  Bin 0 -> 38294 bytes
#  exercise_08/img/pretrained.png                     |  Bin 0 -> 37653 bytes
#  ...events.out.tfevents.1779782103.idassori.49186.1 |  Bin 0 -> 351380 bytes
#  ...events.out.tfevents.1779782029.idassori.49186.0 |  Bin 0 -> 375380 bytes
#  ...events.out.tfevents.1779780389.idassori.35011.1 |  Bin 0 -> 70913 bytes
#  ...events.out.tfevents.1779780267.idassori.35011.0 |  Bin 0 -> 33280 bytes
#  ...events.out.tfevents.1779780496.idassori.35011.2 |  Bin 0 -> 19380 bytes
#  31 files changed, 7005 insertions(+), 74 deletions(-)
#  create mode 100644 exercise_08/1_Autoencoder.ipynb
#  create mode 100644 exercise_08/Optional-BatchNormalization_Dropout.ipynb
#  create mode 100644 exercise_08/exercise_code/.empty
#  create mode 100644 exercise_08/exercise_code/BatchNormModel.py
#  create mode 100644 exercise_08/exercise_code/Util.py
#  create mode 100644 exercise_08/exercise_code/base_dataset.py
#  create mode 100644 exercise_08/exercise_code/download_utils.py
#  create mode 100644 exercise_08/exercise_code/image_folder_dataset.py
#  create mode 100644 exercise_08/exercise_code/layers.py
#  create mode 100644 exercise_08/exercise_code/models.py
#  create mode 100644 exercise_08/exercise_code/submit.py
#  create mode 100644 exercise_08/exercise_code/tests/__init__.py
#  create mode 100644 exercise_08/exercise_code/tests/base_tests.py
#  create mode 100644 exercise_08/exercise_code/tests/eval_utils.py
#  create mode 100644 exercise_08/exercise_code/tests/grad_tests.py
#  create mode 100644 exercise_08/exercise_code/tests/gradient_check_utils.py
#  create mode 100644 exercise_08/img/autoencoder.png
#  create mode 100644 exercise_08/img/batchnorm.jpg
#  create mode 100644 exercise_08/img/dropout.jpg
#  create mode 100644 exercise_08/img/network_split.png
#  create mode 100644 exercise_08/img/pretrained.png
#  create mode 100644 exercise_08/logs/Bn_model_logs/BN-model/events.out.tfevents.1779782103.idassori.49186.1
#  create mode 100644 exercise_08/logs/Bn_model_logs/simple-model/events.out.tfevents.1779782029.idassori.49186.0
#  create mode 100644 exercise_08/logs/ae_logs/run_1/events.out.tfevents.1779780389.idassori.35011.1
#  create mode 100644 exercise_08/logs/cls_logs/run_1/events.out.tfevents.1779780267.idassori.35011.0
#  create mode 100644 exercise_08/logs/pretrained_cls_logs/run_1/events.out.tfevents.1779780496.idassori.35011.2
