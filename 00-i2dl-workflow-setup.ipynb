# %% [markdown]
# # **Workflow Setup Notebook**
# ### Synching the Github repository and Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/i2dl
# !git pull
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/i2dl
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 63 (delta 19), reused 44 (delta 7), pack-reused 0 (from 0)
# Unpacking objects: 100% (63/63), 3.00 MiB | 2.03 MiB/s, done.
# From https://github.com/Louis-codes/TUM_deep_learning
#    32fc26f..bcd4a90  main       -> origin/main
# Updating 32fc26f..bcd4a90
# Updating files: 100% (25/25), done.
# Fast-forward
#  00-i2dl-workflow-setup.ipynb                       |  473 +-----
#  01_math_recap.ipynb                                |   46 +-
#  exercise_07/3_Cifar10_Pytorch.ipynb                |   40 +-
#  exercise_09/1_facial_keypoints.ipynb               | 1772 ++++++++++----------
#  exercise_09/exercise_code/networks/keypoint_nn.py  |   13 +-
#  exercise_10/1_segmentation_nn.ipynb                |    1 +
#  exercise_10/exercise_code/__init__.py              |    0
#  exercise_10/exercise_code/data/__init__.py         |    0
#  exercise_10/exercise_code/data/download_utils.py   |  124 ++
#  .../exercise_code/data/segmentation_dataset.py     |  105 ++
#  exercise_10/exercise_code/networks/__init__.py     |    0
#  .../exercise_code/networks/segmentation_nn.py      |   97 ++
#  exercise_10/exercise_code/tests/__init__.py        |    3 +
#  exercise_10/exercise_code/tests/base_tests.py      |  148 ++
#  exercise_10/exercise_code/tests/eval_utils.py      |   10 +
#  exercise_10/exercise_code/tests/gradient_check.py  |  126 ++
#  .../exercise_code/tests/segmentation_nn_tests.py   |   80 +
#  exercise_10/exercise_code/util/Util.py             |   44 +
#  exercise_10/exercise_code/util/__init__.py         |    5 +
#  exercise_10/exercise_code/util/save_model.py       |   14 +
#  exercise_10/exercise_code/util/submit.py           |   72 +
#  exercise_10/exercise_code/util/vis_utils.py        |   72 +
#  exercise_10/images/input_target.png                |  Bin 0 -> 129230 bytes
#  exercise_10/images/loss_img.png                    |  Bin 0 -> 85253 bytes
#  exercise_10/images/segmentation.jpg                |  Bin 0 -> 108635 bytes
#  25 files changed, 1886 insertions(+), 1359 deletions(-)
#  create mode 100644 exercise_10/1_segmentation_nn.ipynb
#  create mode 100644 exercise_10/exercise_code/__init__.py
#  create mode 100644 exercise_10/exercise_code/data/__init__.py
#  create mode 100644 exercise_10/exercise_code/data/download_utils.py
#  create mode 100644 exercise_10/exercise_code/data/segmentation_dataset.py
#  create mode 100644 exercise_10/exercise_code/networks/__init__.py
#  create mode 100644 exercise_10/exercise_code/networks/segmentation_nn.py
#  create mode 100644 exercise_10/exercise_code/tests/__init__.py
#  create mode 100644 exercise_10/exercise_code/tests/base_tests.py
#  create mode 100644 exercise_10/exercise_code/tests/eval_utils.py
#  create mode 100644 exercise_10/exercise_code/tests/gradient_check.py
#  create mode 100644 exercise_10/exercise_code/tests/segmentation_nn_tests.py
#  create mode 100644 exercise_10/exercise_code/util/Util.py
#  create mode 100644 exercise_10/exercise_code/util/__init__.py
#  create mode 100644 exercise_10/exercise_code/util/save_model.py
#  create mode 100644 exercise_10/exercise_code/util/submit.py
#  create mode 100644 exercise_10/exercise_code/util/vis_utils.py
#  create mode 100644 exercise_10/images/input_target.png
#  create mode 100644 exercise_10/images/loss_img.png
#  create mode 100644 exercise_10/images/segmentation.jpg
