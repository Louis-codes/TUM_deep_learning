# %% [markdown]
# # **Workflow Setup Notebook**
# ### Synching the Github repository and Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/i2dl
# !git pull
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/i2dl
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 17 (delta 3), reused 3 (delta 3), pack-reused 14 (from 1)
# Unpacking objects: 100% (17/17), 216.54 KiB | 194.00 KiB/s, done.
# From https://github.com/Louis-codes/TUM_deep_learning
#    883a8cd..32fc26f  main       -> origin/main
# Updating 883a8cd..32fc26f
# Fast-forward
#  00-i2dl-workflow-setup.ipynb                      |  70 +-
#  exercise_09/1_facial_keypoints.ipynb              | 892 +++++++++++++++++++++-
#  exercise_09/exercise_code/networks/keypoint_nn.py |  43 +-
#  3 files changed, 987 insertions(+), 18 deletions(-)
