# %% [markdown]
# # **Workflow Setup Notebook**
# ### Synching the Github repository and Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/i2dl
# !git pull
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/i2dl
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 22 (delta 11), reused 7 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (22/22), 12.25 KiB | 3.00 KiB/s, done.
# From https://github.com/Louis-codes/TUM_deep_learning
#    bcd4a90..4bfe48c  main       -> origin/main
# Updating bcd4a90..4bfe48c
# Fast-forward
#  00-i2dl-workflow-setup.ipynb                       |  68 +-
#  exercise_10/1_segmentation_nn.ipynb                | 905 ++++++++++++++++++++-
#  .../exercise_code/networks/segmentation_nn.py      |  33 +-
#  3 files changed, 989 insertions(+), 17 deletions(-)
